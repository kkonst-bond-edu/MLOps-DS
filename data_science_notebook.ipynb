# %% [markdown]
# <a href="https://colab.research.google.com/github/kkonst-bond-edu/MLOps-DS/blob/main/data_science_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conlusion
